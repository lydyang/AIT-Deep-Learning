# %% [markdown]
# <a href="https://colab.research.google.com/github/lydyang/AIT-Deep-Learning/blob/main/Lydia_Yang_12_Anomaly_detection_AE_assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Anomaly detection with autoencoders
#
# In this notebook we you have to create a fully-connected neural network based autoencoder in order to detect credit card frauds. In the dataset there are 492 labeled frauds and 284807 normal transactions. First, let's download the dataset and unpack it (original source of the dataset: https://www.kaggle.com/mlg-ulb/creditcardfraud - before downloading the data please read and accept the licence of the original datasource):

# %%
# !wget https://www.deeplearningoktatas.hu/downloads/Anomaly/creditcardfraud.zip
# Out:
# --2024-05-19 14:00:46--  https://www.deeplearningoktatas.hu/downloads/Anomaly/creditcardfraud.zip
# Resolving www.deeplearningoktatas.hu (www.deeplearningoktatas.hu)... 91.227.138.51
# Connecting to www.deeplearningoktatas.hu (www.deeplearningoktatas.hu)|91.227.138.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69155632 (66M) [application/zip]
# Saving to: ‘creditcardfraud.zip’
#
# creditcardfraud.zip 100%[===================>]  65.95M  20.1MB/s    in 3.3s
#
# 2024-05-19 14:00:50 (20.1 MB/s) - ‘creditcardfraud.zip’ saved [69155632/69155632]

# %%
# %%capture
# !unzip creditcardfraud.zip

# %% [markdown]
# ## Imports
# Import the necessary modules:

# %%
import pandas as pd #
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import regularizers
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
np.random.seed(123)

# %% [markdown]
# ## Exercise 1: Reading and preparing the data
# Read the creditcard.csv into a Pandas Dataframe with the [read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) function.

# %%
df = pd.read_csv("creditcard.csv")

# %% [markdown]
# As the next step, select all the columns of the dataframe for the input X, but the "Class" column. And select the "Class" column for output Y. Make sure that both X and Y are two dimensional Numpy arrays.
#
# Hint:
# * you can use df.loc to select rows and columns from a dataframe
# * you can get the Numpy array of a Pandas object with .values, eg. df['myfeature'].values

# %%
X = df.drop('Class', axis=1).values
Y = df['Class'].values

# %%
print("Shape of X:",X.shape)
print("Shape of Y:",Y.shape)
# Out:
# Shape of X: (284807, 30)
# Shape of Y: (284807,)

# %% [markdown]
# Let's standardize the data:

# %%
scaler = preprocessing.StandardScaler().fit(X)
X = scaler.transform(X)

# %% [markdown]
# ## Exercise 2: defining the autoencoder
# Let's define a model according to the following instructions:
# * the model's inputs and outputs should be the same as the number of X's features (columns)
# * the model should have 5 hidden layers, with 16-10-6-10-16 neurons in the hidden layers, respectively
# * all layers but the output should have tanh activation
# * the output layer should have linear activation

# %%
nb_features = X.shape[1]

model = Sequential()
model.add(Dense(16, activation='tanh', input_shape=(nb_features,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(16, activation='tanh'))
model.add(Dense(6, activation='tanh'))
model.add(Dense(10, activation='tanh'))
model.add(Dense(16, activation='tanh'))
model.add(Dense(nb_features, activation="linear"))

# %% [markdown]
# ## Exercise 3: define early stopping compile the model, and train it
# Please pay attention to the following details:
# * use EarlyStopping with patience 10 and this time monitor the training loss
# * do not define validation data
# * use mean squarred error loss function
# * both the input and output of the model should be X this time. (as we are "auto encoding" the input to the output)

# %%
patience = 10
es = EarlyStopping(patience=patience, restore_best_weights=True, monitor="loss")
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# %%
history= model.fit(X,
                   X,
                   epochs=200,
                   callbacks=[es])
# Out:
# Epoch 1/200
# 8901/8901 [==============================] - 41s 4ms/step - loss: 0.7354 - accuracy: 0.2789
# Epoch 2/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.6191 - accuracy: 0.3616
# Epoch 3/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.5673 - accuracy: 0.3952
# Epoch 4/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.5448 - accuracy: 0.4066
# Epoch 5/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.5291 - accuracy: 0.4189
# Epoch 6/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.5133 - accuracy: 0.4261
# Epoch 7/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.5071 - accuracy: 0.4269
# Epoch 8/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.5029 - accuracy: 0.4280
# Epoch 9/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4999 - accuracy: 0.4297
# Epoch 10/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4946 - accuracy: 0.4331
# Epoch 11/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4864 - accuracy: 0.4445
# Epoch 12/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4814 - accuracy: 0.4486
# Epoch 13/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4781 - accuracy: 0.4488
# Epoch 14/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4761 - accuracy: 0.4568
# Epoch 15/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4716 - accuracy: 0.4680
# Epoch 16/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4694 - accuracy: 0.4688
# Epoch 17/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4674 - accuracy: 0.4669
# Epoch 18/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4666 - accuracy: 0.4667
# Epoch 19/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4661 - accuracy: 0.4663
# Epoch 20/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4649 - accuracy: 0.4651
# Epoch 21/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4645 - accuracy: 0.4655
# Epoch 22/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4635 - accuracy: 0.4645
# Epoch 23/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4637 - accuracy: 0.4639
# Epoch 24/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4625 - accuracy: 0.4627
# Epoch 25/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4629 - accuracy: 0.4622
# Epoch 26/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4620 - accuracy: 0.4618
# Epoch 27/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4615 - accuracy: 0.4616
# Epoch 28/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4610 - accuracy: 0.4609
# Epoch 29/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4612 - accuracy: 0.4612
# Epoch 30/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4612 - accuracy: 0.4601
# Epoch 31/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4604 - accuracy: 0.4592
# Epoch 32/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4603 - accuracy: 0.4594
# Epoch 33/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4598 - accuracy: 0.4590
# Epoch 34/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4599 - accuracy: 0.4595
# Epoch 35/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4595 - accuracy: 0.4583
# Epoch 36/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4589 - accuracy: 0.4589
# Epoch 37/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4597 - accuracy: 0.4585
# Epoch 38/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4583 - accuracy: 0.4599
# Epoch 39/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4593 - accuracy: 0.4600
# Epoch 40/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4583 - accuracy: 0.4607
# Epoch 41/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4581 - accuracy: 0.4612
# Epoch 42/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4587 - accuracy: 0.4604
# Epoch 43/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4579 - accuracy: 0.4610
# Epoch 44/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4573 - accuracy: 0.4610
# Epoch 45/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4576 - accuracy: 0.4602
# Epoch 46/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4572 - accuracy: 0.4615
# Epoch 47/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4579 - accuracy: 0.4610
# Epoch 48/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4569 - accuracy: 0.4613
# Epoch 49/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4576 - accuracy: 0.4618
# Epoch 50/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4564 - accuracy: 0.4617
# Epoch 51/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4570 - accuracy: 0.4618
# Epoch 52/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4565 - accuracy: 0.4617
# Epoch 53/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4572 - accuracy: 0.4625
# Epoch 54/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4564 - accuracy: 0.4631
# Epoch 55/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4571 - accuracy: 0.4626
# Epoch 56/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4565 - accuracy: 0.4626
# Epoch 57/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4568 - accuracy: 0.4628
# Epoch 58/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4557 - accuracy: 0.4632
# Epoch 59/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4557 - accuracy: 0.4637
# Epoch 60/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4552 - accuracy: 0.4637
# Epoch 61/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4557 - accuracy: 0.4635
# Epoch 62/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4565 - accuracy: 0.4640
# Epoch 63/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4554 - accuracy: 0.4640
# Epoch 64/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4563 - accuracy: 0.4635
# Epoch 65/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4554 - accuracy: 0.4641
# Epoch 66/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4557 - accuracy: 0.4640
# Epoch 67/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4559 - accuracy: 0.4641
# Epoch 68/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4556 - accuracy: 0.4641
# Epoch 69/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4553 - accuracy: 0.4647
# Epoch 70/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4549 - accuracy: 0.4643
# Epoch 71/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4554 - accuracy: 0.4641
# Epoch 72/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4549 - accuracy: 0.4640
# Epoch 73/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4558 - accuracy: 0.4644
# Epoch 74/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4556 - accuracy: 0.4645
# Epoch 75/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4556 - accuracy: 0.4654
# Epoch 76/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4545 - accuracy: 0.4657
# Epoch 77/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4549 - accuracy: 0.4650
# Epoch 78/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4553 - accuracy: 0.4653
# Epoch 79/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4551 - accuracy: 0.4642
# Epoch 80/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4540 - accuracy: 0.4653
# Epoch 81/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4555 - accuracy: 0.4655
# Epoch 82/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4540 - accuracy: 0.4651
# Epoch 83/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4539 - accuracy: 0.4651
# Epoch 84/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4552 - accuracy: 0.4642
# Epoch 85/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4547 - accuracy: 0.4651
# Epoch 86/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4547 - accuracy: 0.4646
# Epoch 87/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4538 - accuracy: 0.4649
# Epoch 88/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4544 - accuracy: 0.4647
# Epoch 89/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4544 - accuracy: 0.4642
# Epoch 90/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4549 - accuracy: 0.4648
# Epoch 91/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4540 - accuracy: 0.4644
# Epoch 92/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4541 - accuracy: 0.4645
# Epoch 93/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4539 - accuracy: 0.4645
# Epoch 94/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4540 - accuracy: 0.4644
# Epoch 95/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4542 - accuracy: 0.4644
# Epoch 96/200
# 8901/8901 [==============================] - 37s 4ms/step - loss: 0.4536 - accuracy: 0.4646
# Epoch 97/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4538 - accuracy: 0.4646
# Epoch 98/200
# 8901/8901 [==============================] - 37s 4ms/step - loss: 0.4535 - accuracy: 0.4646
# Epoch 99/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4541 - accuracy: 0.4639
# Epoch 100/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4542 - accuracy: 0.4641
# Epoch 101/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4533 - accuracy: 0.4640
# Epoch 102/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4531 - accuracy: 0.4639
# Epoch 103/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4526 - accuracy: 0.4646
# Epoch 104/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4534 - accuracy: 0.4645
# Epoch 105/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4530 - accuracy: 0.4641
# Epoch 106/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4537 - accuracy: 0.4637
# Epoch 107/200
# 8901/8901 [==============================] - 38s 4ms/step - loss: 0.4523 - accuracy: 0.4637
# Epoch 108/200
# 8901/8901 [==============================] - 37s 4ms/step - loss: 0.4523 - accuracy: 0.4641
# Epoch 109/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4527 - accuracy: 0.4637
# Epoch 110/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4531 - accuracy: 0.4635
# Epoch 111/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4528 - accuracy: 0.4637
# Epoch 112/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4521 - accuracy: 0.4636
# Epoch 113/200
# 8901/8901 [==============================] - 37s 4ms/step - loss: 0.4524 - accuracy: 0.4639
# Epoch 114/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4536 - accuracy: 0.4632
# Epoch 115/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4522 - accuracy: 0.4644
# Epoch 116/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4523 - accuracy: 0.4644
# Epoch 117/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4521 - accuracy: 0.4642
# Epoch 118/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4520 - accuracy: 0.4642
# Epoch 119/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4527 - accuracy: 0.4644
# Epoch 120/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4531 - accuracy: 0.4642
# Epoch 121/200
# 8901/8901 [==============================] - 37s 4ms/step - loss: 0.4525 - accuracy: 0.4639
# Epoch 122/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4528 - accuracy: 0.4640
# Epoch 123/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4519 - accuracy: 0.4647
# Epoch 124/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4524 - accuracy: 0.4640
# Epoch 125/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4518 - accuracy: 0.4645
# Epoch 126/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4527 - accuracy: 0.4643
# Epoch 127/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4526 - accuracy: 0.4642
# Epoch 128/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4519 - accuracy: 0.4642
# Epoch 129/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4520 - accuracy: 0.4644
# Epoch 130/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4521 - accuracy: 0.4637
# Epoch 131/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4517 - accuracy: 0.4644
# Epoch 132/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4527 - accuracy: 0.4641
# Epoch 133/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4513 - accuracy: 0.4642
# Epoch 134/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4524 - accuracy: 0.4639
# Epoch 135/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4514 - accuracy: 0.4647
# Epoch 136/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4527 - accuracy: 0.4635
# Epoch 137/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4514 - accuracy: 0.4644
# Epoch 138/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4516 - accuracy: 0.4644
# Epoch 139/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4509 - accuracy: 0.4649
# Epoch 140/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4510 - accuracy: 0.4645
# Epoch 141/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4511 - accuracy: 0.4644
# Epoch 142/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4522 - accuracy: 0.4639
# Epoch 143/200
# 8901/8901 [==============================] - 37s 4ms/step - loss: 0.4523 - accuracy: 0.4643
# Epoch 144/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4510 - accuracy: 0.4650
# Epoch 145/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4516 - accuracy: 0.4643
# Epoch 146/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4517 - accuracy: 0.4648
# Epoch 147/200
# 8901/8901 [==============================] - 36s 4ms/step - loss: 0.4520 - accuracy: 0.4646
# Epoch 148/200
# 8901/8901 [==============================] - 37s 4ms/step - loss: 0.4509 - accuracy: 0.4652
# Epoch 149/200
# 8901/8901 [==============================] - 35s 4ms/step - loss: 0.4516 - accuracy: 0.4650

# %% [markdown]
# ## Results analysis
# After training is done, we make predictions for the complete dataset and inspect the reconstruction loss. Our assumption is that, higher reconstruction loss are more likely to belong to anomalies than lower reconstruciton loss.

# %%
preds = model.predict(X)
errs  = np.square(preds-X)
errs  = np.mean(errs,axis=1)
# Out:
# 8901/8901 [==============================] - 15s 2ms/step

# %%
plt.figure(figsize=(16,10))
rng = np.arange(len(errs))
colors = ['g','r'] # green: normal, red: anomaly
for i in [0,1]:
    plt.scatter(rng[(Y==i).reshape(-1)], errs[(Y==i).reshape(-1)], color=colors[i])

# %%
Y_cut    = Y[errs<10]
errs_cut = errs[errs<10]

# %%
plt.figure(figsize=(16,10))
rng = np.arange(len(errs_cut))
colors = ['g','r']
for i in [0,1]:
    plt.scatter(rng[(Y_cut==i).reshape(-1)], errs_cut[(Y_cut==i).reshape(-1)], color=colors[i])

# %% [markdown]
# ## Exercise 4: finding the right treshold
# Find a treshold that identifies at least 130 anomalies correctly with as small number of missclassifications of non-anomalies as possible.

# %%
threshold = 3.4
errs_filtered               = errs[errs>threshold]
Y_filtered                  = Y[errs>threshold]
errs_filtered_non_anomalies = errs[errs<=threshold]
Y_filtered_non_anomalies    = Y[errs<=threshold]

print("Anomalies in the dataset") # Y_filtered==1
print("   predicted as anomaly:", len(errs_filtered[Y_filtered==1]))
print("   predicted as non-anomaly: ", len(errs_filtered_non_anomalies[Y_filtered_non_anomalies==1]) )
print("Non-anomalies in the dataset") # Y_filtered ==0
print("   predicted as anomaly:", len(errs_filtered[Y_filtered==0]))
print("   predicted as non-anomaly:", len(errs_filtered_non_anomalies[Y_filtered_non_anomalies==0]) )
# Out:
# Anomalies in the dataset
#    predicted as anomaly: 132
#    predicted as non-anomaly:  360
# Non-anomalies in the dataset
#    predicted as anomaly: 3013
#    predicted as non-anomaly: 281302

# %% [markdown]
# We can also inspect the confusion matrix:

# %%
from sklearn.metrics import confusion_matrix
conf=confusion_matrix(Y, errs>threshold)
import seaborn as sns
sns.heatmap(conf, annot=True, vmax=8000, fmt="d")
# Out:
# <Axes: >
